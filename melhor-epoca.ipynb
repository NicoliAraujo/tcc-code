# %%
import pandas as pd

# %%
df = pd.read_csv('callbacks/vgg16/age/consolidados/history-regression-abordagem7-relu.csv')

# %%
df.head()
# Out:
#    epoch       loss  mean_squared_error   val_loss  val_mean_squared_error
# 0      0  14.779488         4331.853675  11.217153              203.733874
# 1      1  11.329389          214.109514  11.246205              202.965223
# 2      2  11.341390          214.248915  11.175663              209.132454
# 3      3  11.303812          212.955136  11.199557              211.091900
# 4      4  11.289758          212.863905  11.225267              213.065495

# %%
df.sort_values('val_loss')
# Out:
#     epoch       loss  mean_squared_error   val_loss  val_mean_squared_error
# 21     21  11.261584          211.756307  11.160434              205.354216
# 12     12  11.268622          212.459837  11.162914              206.010868
# 40     40  11.257905          211.807298  11.163528              206.136413
# 51     51  11.253587          211.591974  11.163817              206.196320
# 20     20  11.261914          211.616959  11.164110              206.257712
# 17     17  11.268606          211.942060  11.164243              206.285539
# 33     33  11.255685          211.510306  11.164477              205.069654
# 37     37  11.256181          211.753090  11.164972              205.036006
# 46     46  11.258494          211.654654  11.165448              205.003917
# 36     36  11.262160          211.944003  11.165725              204.985355
# 47     47  11.258243          211.782776  11.165792              206.620845
# ...
