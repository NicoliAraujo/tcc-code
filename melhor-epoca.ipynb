# %%
import pandas as pd

# %%
df = pd.read_csv('callbacks/vgg16/age/consolidados/history-regression-abordagem9-lrelu.csv')
#df = pd.read_csv('callbacks/squeeze/age/consolidados/history-regression-abordagem-squeeze1-relu.csv')

# %%
df.head()
# Out:
#    epoch       loss  mean_squared_error   val_loss  val_mean_squared_error
# 0      0  13.437821         1815.986529  11.278143              202.741713
# 1      1  11.335991          214.091833  11.254463              215.566038
# 2      2  11.325953          213.948862  11.164460              206.331561
# 3      3  11.324818          213.779372  11.167085              206.912729
# 4      4  11.303097          213.177162  11.169003              204.772207

# %%
df.sort_values('val_loss')
# Out:
#     epoch       loss  mean_squared_error   val_loss  val_mean_squared_error
# 81     81  11.257184          211.655275  11.159761              205.406160
# 63     63  11.254924          211.551717  11.159988              205.447511
# 48     48  11.262952          211.898586  11.160290              205.364671
# 42     42  11.262065          212.002632  11.160401              205.523534
# 32     32  11.262523          211.941972  11.160911              205.619126
# 73     73  11.255665          211.497892  11.160972              205.630531
# 61     61  11.257135          211.460898  11.161387              205.709830
# 60     60  11.257811          211.898318  11.161446              205.721194
# 18     18  11.271615          212.199092  11.161478              205.727340
# 69     69  11.254346          211.433727  11.161676              205.765645
# 57     57  11.257955          211.832082  11.161750              205.259626
# ...
