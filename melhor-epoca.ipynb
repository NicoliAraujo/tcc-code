# %%
import pandas as pd

# %%
df = pd.read_csv('callbacks/lenet/age/consolidados/history-regression-abordagem-5-relu.csv')

# %%
df.head()
# Out:
#    epoch       loss  mean_squared_error   val_loss  val_mean_squared_error
# 0      0  11.787199          233.384754  10.710873              188.755555
# 1      1  10.859027          196.642491  10.735814              195.615834
# 2      2  10.670410          190.323891  10.411555              179.395972
# 3      3  10.429914          183.181870  10.450142              175.707899
# 4      4  10.228069          177.723754  10.350632              173.571363

# %%
df.sort_values('val_loss')
# Out:
#     epoch       loss  mean_squared_error   val_loss  val_mean_squared_error
# 8       8   8.982497          144.497288  10.041809              169.135889
# 10     10   8.333514          129.043272  10.159408              172.480091
# 7       7   9.380152          154.780732  10.165417              171.931573
# 12     12   7.518880          110.546965  10.227520              175.328195
# 9       9   8.643481          136.487242  10.248419              172.061043
# 6       6   9.636846          160.834759  10.266600              179.352140
# 13     13   7.129316          101.516772  10.272024              179.202530
# 14     14   6.712181           92.578281  10.284089              175.912604
# 4       4  10.228069          177.723754  10.350632              173.571363
# 2       2  10.670410          190.323891  10.411555              179.395972
# 3       3  10.429914          183.181870  10.450142              175.707899
# ...
