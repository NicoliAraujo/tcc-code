# %%
import pandas as pd
import numpy as np
from data_generator.batch_generator import BatchGenerator
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint#, TensorBoard
import pickle
from models import AlexNet, LeNetRegressor
from keras import backend as K
K.set_image_data_format('channels_last')
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-96804e8a0427> in <module>()
#       5 from keras.callbacks import ModelCheckpoint#, TensorBoard
#       6 import pickle
# ----> 7 from models import AlexNet, LeNetRegressor
#       8 from keras import backend as K
#       9 K.set_image_data_format('channels_last')
#
# ImportError: cannot import name 'LeNetRegressor'

# %%
test_dataset = BatchGenerator(box_output_format=['class_id'])

# %%
import pandas as pd

# %%
df = pd.read_csv('/home/nicoli/github/alexnet/dataset/csv/imdb_csv/imdb_age_regression.csv')
#df.to_csv('/home/nicoli/github/ssd_keras/dataset/csv/imdb_csv/imdb_age_regression.csv', index=False)
df
# Out:
#        Unnamed: 0                                         image_name  class_id
# 0               0   imdb/79/nm0000379_rm537499648_1982-4-30_2006.jpg        24
# 1               1   imdb/50/nm0001650_rm281973760_1970-3-20_2005.jpg        35
# 2               2  imdb/38/nm0001638_rm3096615168_1941-6-10_1999.jpg        58
# 3               3  imdb/69/nm0358669_rm2779157248_1955-10-8_2008.jpg        53
# 4               4  imdb/07/nm0000207_rm2705034752_1980-2-12_1995.jpg        15
# 5               5  imdb/07/nm0005207_rm1743490304_1955-3-28_2005.jpg        50
# 6               6  imdb/95/nm0472595_rm1674412800_1982-11-12_2004...        22
# 7               7   imdb/71/nm0000671_rm2919406336_1955-8-4_2000.jpg        45
# 8               8  imdb/51/nm0005351_rm1274649344_1976-10-23_2005...        29
# 9               9  imdb/82/nm0242882_rm2574955520_1969-12-11_2011...        42
# 10             10   imdb/74/nm0000874_rm651746816_1956-12-2_2013.jpg        57
# 11             11  imdb/35/nm0000235_rm2839915520_1970-4-29_2012.jpg        42
# 12             12  imdb/42/nm1719342_rm3445535488_1982-5-11_2011.jpg        29
# 13             13   imdb/01/nm0365501_rm2632161536_1982-4-6_2006.jpg        24
# 14             14  imdb/42/nm0755442_rm2276101376_1959-1-16_2005.jpg        46
# 15             15  imdb/37/nm0000837_rm3466304256_1945-8-16_2006.jpg        61
# 16             16  imdb/12/nm0754512_rm2552346624_1992-6-14_2011.jpg        19
# 17             17  imdb/37/nm0930637_rm3858933504_1966-3-14_2013.jpg        47
# 18             18  imdb/28/nm0001728_rm2216400896_1943-11-12_1999...        56
# 19             19  imdb/05/nm2915105_rm1987507200_1985-4-20_2015.jpg        30
# 20             20  imdb/81/nm0124481_rm2331816448_1968-6-27_2011.jpg        43
# 21             21   imdb/39/nm0004839_rm1677956096_1963-8-1_2008.jpg        45
# 22             22  imdb/09/nm0675409_rm2528086528_1963-9-25_2008.jpg        45
# 23             23   imdb/60/nm1446060_rm813017088_1987-5-13_2005.jpg        18
# 24             24  imdb/26/nm1843026_rm3255022592_1982-10-19_2012...        30
# 25             25  imdb/48/nm0951148_rm1967824896_1985-5-10_2013.jpg        28
# 26             26  imdb/63/nm0000263_rm3426127360_1951-1-12_1988.jpg        37
# 27             27  imdb/03/nm2088803_rm3254169600_1982-7-30_2011.jpg        29
# 28             28    imdb/32/nm0671032_rm707706112_1965-4-9_2010.jpg        45
# 29             29   imdb/80/nm0814280_rm609207040_1967-1-17_2011.jpg        44
# ...           ...                                                ...       ...
# 47920       47920  imdb/86/nm0552086_rm3766925824_1962-7-10_1990.jpg        28
# 47921       47921   imdb/56/nm1812656_rm664727808_1979-4-15_2015.jpg        36
# 47922       47922  imdb/37/nm0000337_rm1862441728_1979-10-4_2000.jpg        21
# 47923       47923   imdb/08/nm0001608_rm2621290752_1970-4-4_2011.jpg        41
# 47924       47924   imdb/52/nm0761052_rm3120797184_1973-4-2_2008.jpg        35
# 47925       47925  imdb/27/nm0503627_rm3525417472_1941-6-22_2005.jpg        64
# 47926       47926   imdb/74/nm0000474_rm1128067584_1951-9-5_2015.jpg        64
# 47927       47927   imdb/21/nm0000421_rm4036466176_1968-1-2_2008.jpg        40
# 47928       47928  imdb/74/nm0001774_rm231053312_1965-11-30_1999.jpg        34
# 47929       47929  imdb/19/nm0000219_rm2999842560_1952-4-10_2015.jpg        63
# 47930       47930   imdb/89/nm0915989_rm2271128320_1960-4-4_2012.jpg        52
# 47931       47931   imdb/68/nm0551368_rm1874822144_1975-7-9_2009.jpg        34
# 47932       47932  imdb/61/nm0906261_rm1614662656_1954-10-31_1979...        25
# 47933       47933  imdb/64/nm0570364_rm2994643712_1971-11-20_2013...        42
# 47934       47934  imdb/50/nm0000250_rm2610926592_1969-4-25_2008.jpg        39
# 47935       47935   imdb/62/nm0001062_rm1558094592_1954-9-9_2012.jpg        58
# 47936       47936   imdb/33/nm0366433_rm855874048_1950-11-8_2006.jpg        56
# 47937       47937  imdb/26/nm0001426_rm756256256_1943-12-31_1990.jpg        47
# 47938       47938  imdb/76/nm0657076_rm3115883264_1976-8-15_2003.jpg        27
# 47939       47939  imdb/35/nm0262635_rm3973889792_1981-6-13_2011.jpg        30
# 47940       47940  imdb/54/nm0840754_rm1864888832_1988-10-21_2015...        27
# 47941       47941  imdb/68/nm0909768_rm551539968_1964-10-13_2013.jpg        49
# 47942       47942   imdb/80/nm0000380_rm1430490624_1931-1-5_2009.jpg        78
# 47943       47943  imdb/25/nm0821325_rm3276118784_1965-9-14_2005.jpg        40
# 47944       47944  imdb/34/nm0295334_rm2923605760_1949-4-24_2011.jpg        62
# 47945       47945  imdb/46/nm0193846_rm2767057408_1982-11-30_2015...        33
# 47946       47946  imdb/47/nm0944647_rm3319508480_1969-1-22_2012.jpg        43
# 47947       47947   imdb/07/nm5396707_rm660330752_1994-2-28_2011.jpg        17
# 47948       47948   imdb/79/nm0316079_rm1960675328_1967-6-6_2009.jpg        42
# 47949       47949   imdb/72/nm0134072_rm2241173760_1970-5-3_2003.jpg        33
#
# [47950 rows x 3 columns]

# %%
test_dataset.parse_csv(labels_filename='/home/nicoli/github/alexnet/dataset/csv/imdb_csv/imdb_age_regression_test_split_47950-70-10-20.csv',
                        images_dir='/home/nicoli/github/alexnet/dataset/imdb-hand-crop/',
                        input_format=['image_name', 'class_id'])

# %%
img_height, img_width, img_depth = (224,224,3)

#epochs = 90

batch_size=int(test_dataset.get_n_samples()/10)
shuffle = True
ssd_train = False

validation_batch_size = 1


# In[15]:

test_generator = test_dataset.generate(batch_size=validation_batch_size,
                                       shuffle=shuffle,
                                       ssd_train=ssd_train,
                                       #flip=0.5,
                                       #translate=[(0,30),(0,30), 0.5],
                                       #equalize=True,
                                       returns={'processed_labels'},
                                       resize=(img_height, img_width))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
##out = next(test_generator)
#plt.imshow(out[0][0]), out[1]

# %%
from data_generator.batch_generator import _translate, histogram_eq, _brightness, _scale

# %%
out = next(test_generator)

# %%
out[0][0].shape
# Out:
# (224, 224, 3)

# %%
import cv2

# %%
translate = _translate(out[0][0], (0,30), (0,30))

plt.imshow(translate[0])

# %%
scale = _scale(out[0][0], 0.6, 1)
plt.imshow(scale[0])

# %%
out = next(test_generator)
plt.imshow(out[0][0]), out[1]
# Out:
# (<matplotlib.image.AxesImage at 0x7ff9188555c0>, array([[30]]))

# %%
out[0].shape
# Out:
# (4795, 224, 224, 3)

# %%
mean = np.mean(out[0], axis=0)

# %%
mean = mean.astype(int)

# %%
plt.imshow(mean)

# %%
std = np.std(out[0], axis=0).astype(int)

# %%
plt.imshow(std)
